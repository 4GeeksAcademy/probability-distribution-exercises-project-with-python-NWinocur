# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment; for example, when you flip a coin, it can be either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution, where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %% [markdown]
# #### Normal Distribution
# ##### Defining probability functions

# %%
from scipy.stats import norm

# Define all the probability functions related to this distribution

def dnorm(x, mean=0, sd=1):
    """
    Calculates the point estimate of the normal distribution
    """
    result = norm.pdf(x, loc=mean, scale=sd)

    return result

def pnorm(x, mean=0, sd=1):
    """
    Calculates the cumulative of the normal distribution
    """
    result = norm.cdf(x, loc=mean, scale=sd)

    return result

def qnorm(x, mean=0, sd=1):
    """
    Calculates the quantile function from the normal distribution
    """
    result = norm.ppf(x, loc=mean, scale=sd)

    return result

def rnorm(size, mean=0, sd=1):
    """
    Generates random variables from the normal distribution
    """
    result = norm.rvs(loc= mean, scale=sd, size=size)

    return result

# %% [markdown]
# ##### Printing probability statements about normal distribution

# %%
import numpy as np

np.random.seed(42)
mean_loc = 0

print(f"Probability that a normal distribution takes the value 1.96: {dnorm(1.96, mean=mean_loc, sd=1)}")
print(f"Probability that a normal distribution will take a value less than 1.96: {pnorm(1.96, mean=mean_loc, sd=1)}")
print(f"Which value of a normal distribution has 97.5 of observations under it? {qnorm(0.975, mean=mean_loc, sd=1)}")
print(f"Generate 2000 random values from a normal distribution: {rnorm(2000, mean=mean_loc, sd=1)}")
# Out:
# Probability that a normal distribution takes the value 1.96: 0.058440944333451476
# Probability that a normal distribution will take a value less than 1.96: 0.9750021048517795
# Which value of a normal distribution has 97.5 of observations under it? 1.959963984540054
# Generate 2000 random values from a normal distribution: [ 0.49671415 -0.1382643   0.64768854 ... -0.88187465 -0.16306696
#  -0.74490264]

# %% [markdown]
# ##### Plotting

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

scale = 1
loc = mean_loc
size = 2000
data = rnorm(size, loc, scale)

pmf = dnorm(data, loc, scale)
cdf = pnorm(data, loc, scale)
ppf = qnorm(data, loc, scale)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #### Uniform Distribution
# ##### Defining probability functions

# %%
from scipy.stats import uniform

# Define all the probability functions related to this distribution

def duniform(x, mean, sd):
    """
    Calculates the point estimate of the uniform distribution
    """
    result = uniform.pdf(x, loc=mean, scale=sd)

    return result

def puniform(x, mean, sd):
    """
    Calculates the cumulative of the uniform distribution
    """
    result = uniform.cdf(x, loc=mean, scale=sd)

    return result

def quniform(x, mean=0, sd=1):
    """
    Calculates the quantile function from the uniform distribution
    """
    result = uniform.ppf(x, loc=mean, scale=sd)

    return result

def runiform(size, mean=0, sd=1):
    """
    Generates random variables from the uniform distribution
    """
    result = uniform.rvs(loc= mean, scale=sd, size=size)

    return result

# %% [markdown]
# ##### Printing probability statements about uniform distribution

# %%
import numpy as np

np.random.seed(42)
mean_loc = 1.96

print(f"Probability that a uniform distribution takes the value 1.96: {duniform(1.96, mean=mean_loc, sd=1)}")
print(f"Probability that a uniform distribution will take a value less than 1.96: {puniform(1.96, mean=mean_loc, sd=1)}")
print(f"Which value of a uniform distribution has 97.5 of observations under it? {quniform(0.975, mean=mean_loc, sd=1)}")
print(f"Generate 2000 random values from a uniform distribution: {runiform(2000, mean=mean_loc, sd=1)}")
# Out:
# Probability that a uniform distribution takes the value 1.96: 1.0
# Probability that a uniform distribution will take a value less than 1.96: 0.0
# Which value of a uniform distribution has 97.5 of observations under it? 2.935
# Generate 2000 random values from a uniform distribution: [2.33454012 2.91071431 2.69199394 ... 2.02895802 2.01705472 2.24218707]

# %% [markdown]
# ##### Plotting

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

scale = 1
loc = mean_loc
size = 2000
data = runiform(size, loc, scale)

pmf = duniform(data, loc, scale)
cdf = puniform(data, loc, scale)
ppf = quniform(data, loc, scale)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
